# %% [markdown]
# <a href="https://colab.research.google.com/github/Somu112/Predictive-Analysis/blob/master/Statistics_Part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Scenario-3 FIFA**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !wget https://www.dropbox.com/s/2m892ugv2m8mmnu/Fifa.csv?dl=0
# Out:
# --2021-04-14 13:02:27--  https://www.dropbox.com/s/2m892ugv2m8mmnu/Fifa.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.7.18, 2620:100:6030:18::a27d:5012
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.7.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/2m892ugv2m8mmnu/Fifa.csv [following]
# --2021-04-14 13:02:27--  https://www.dropbox.com/s/raw/2m892ugv2m8mmnu/Fifa.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucd90155f32b8bd029032c97a4ec.dl.dropboxusercontent.com/cd/0/inline/BMnfDK0NaHqTnZUoLyz4lzddyCF9_4rKVtckoeuA0XhsqH_PUciCtu6ioTdkIVRmSai-DRZSHWf72L0Rg3Oq5cOKAFtDw0S21zKleWuTRhZsL7cYXEkogev0A7Z3yZqpOeDRzo8_Nf7GOsF3POOPFsrI/file# [following]
# ...

# %%
fifa = pd.read_csv("Fifa.csv?dl=0")
fifa.head()
# Out:
#    Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0           0  158023  ...        8.0         €226.5M
# 1           1   20801  ...       11.0         €127.1M
# 2           2  190871  ...       11.0         €228.1M
# 3           3  193080  ...       94.0         €138.6M
# 4           4  192985  ...       13.0         €196.4M
#
# [5 rows x 89 columns]

# %%
sns.jointplot(x=fifa['Age'],y=fifa['Potential'],
              joint_kws={'alpha':0.1,'s':3,'color':'blue'},
              marginal_kws={'color':'blue'})

# %% [markdown]
# Question-2: Visualize the sprint speed of players as their age progresses. Write your observation

# %%
sns.lmplot(data=fifa, x='Age', y='SprintSpeed',lowess=True,scatter_kws={'alpha':0.01,'s':3,'color':'blue'},
           line_kws={'color':'green'})
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# Question-3: Visualize to find whether the players are right or left footed

# %%
sns.lmplot(x='BallControl',y='Dribbling',data=fifa,col='Preferred Foot',scatter_kws={'alpha':0.1,'color':'yellow'},
           line_kws={'color':'black'})

# %% [markdown]
# Question-4: Compare the Overall Scores and age with respect to player's Preferred foot

# %%
plt.rcParams['figure.figsize'] = (20,7)
plt.style.use('seaborn-dark-palette')

sns.boxplot(fifa['Overall'],fifa['Age'],hue=fifa['Preferred Foot'],palette='rocket')
plt.title('Comparison of Overall score and age wrt preffered foot', fontsize=20)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Scenario-4 COVID-19**

# %%
# !wget https://www.dropbox.com/s/g2dqld706ni0we7/AgeGroupDetails.csv?dl=0
# Out:
# --2021-04-14 13:02:34--  https://www.dropbox.com/s/g2dqld706ni0we7/AgeGroupDetails.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.7.18, 2620:100:6019:18::a27d:412
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.7.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/g2dqld706ni0we7/AgeGroupDetails.csv [following]
# --2021-04-14 13:02:34--  https://www.dropbox.com/s/raw/g2dqld706ni0we7/AgeGroupDetails.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucf43f9bb955624a019ca7b2637e.dl.dropboxusercontent.com/cd/0/inline/BMkwDwrkon_2znaazCweKy2BgZ0pWdkj6RLRX173yFr5SlwS55IdOUTCX3APp9sTL62jHUyj2tH_6Y0DMpNB5jYbp-FvR4no7kQsWUi8bj2bHJderAVVL7yGYRE11z-RGeAtpm92gTP5z8pnaJAfDQ9G/file# [following]
# ...

# %%
# !wget https://www.dropbox.com/s/o5vzztftk1oya89/covid_19_india.csv?dl=0
# Out:
# --2021-04-14 13:02:35--  https://www.dropbox.com/s/o5vzztftk1oya89/covid_19_india.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.7.18, 2620:100:6019:18::a27d:412
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.7.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/o5vzztftk1oya89/covid_19_india.csv [following]
# --2021-04-14 13:02:35--  https://www.dropbox.com/s/raw/o5vzztftk1oya89/covid_19_india.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucc574f4055401a661f1d3d7bbb4.dl.dropboxusercontent.com/cd/0/inline/BMkwjh4O_MMvswPhge7ROaCcMIkRaXGvfeCNE9pAaVyNFwP68FSo26StJ1DzKz0Y5rgFAcGPu_l-iGOeeJtk-abKXkLinSviiAUfLHsQChsbUjwbBaPor89YEFADgm35-fpSgdOSVYuQ5hBsPITtON7R/file# [following]
# ...

# %%
# !wget https://www.dropbox.com/s/8ffhufns6yi1hic/HospitalBedsIndia.csv?dl=0
# Out:
# --2021-04-14 13:02:36--  https://www.dropbox.com/s/8ffhufns6yi1hic/HospitalBedsIndia.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.7.18, 2620:100:6019:18::a27d:412
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.7.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/8ffhufns6yi1hic/HospitalBedsIndia.csv [following]
# --2021-04-14 13:02:36--  https://www.dropbox.com/s/raw/8ffhufns6yi1hic/HospitalBedsIndia.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc7bd938fdbd1d016f35b2552990.dl.dropboxusercontent.com/cd/0/inline/BMnSOAjAwWbzHmyC339sOT5gR1sfiwHv3Zq4jgdbeXR-zFlX5eoWeb0koVDyiRAIGNVL1R5JZYsJX3yRe_Z6mmpmZBG1HK-z3L1qtAF-n9hGcz857dhSYwpQihz_pFTXXp9xIjR1UzWpS0NIKyfO-mIR/file# [following]
# ...

# %%
# !wget https://www.dropbox.com/s/v6ts2rdf7kxn93v/datasets_507962_1091873_population_by_country_2020.csv?dl=0
# Out:
# --2021-04-14 13:02:37--  https://www.dropbox.com/s/v6ts2rdf7kxn93v/datasets_507962_1091873_population_by_country_2020.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.7.18, 2620:100:6019:18::a27d:412
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.7.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/v6ts2rdf7kxn93v/datasets_507962_1091873_population_by_country_2020.csv [following]
# --2021-04-14 13:02:38--  https://www.dropbox.com/s/raw/v6ts2rdf7kxn93v/datasets_507962_1091873_population_by_country_2020.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc14b8f3cc28847c44928ed30b3b.dl.dropboxusercontent.com/cd/0/inline/BMmSES-UJF8sFNay6OYatpGV4-hT7hklBMN5tZTH-NyvBzGOseXL6uzYQsnYuONphZU34HTm2ki3Z6HPk_RbJnN6s7OzYGv8gW9ocXK4bOnb9yLHvlGjt_JRVlwOpzfC958TTNb_2ucJcvY50iQki0cM/file# [following]
# ...

# %%
# importing the dataset
age_details = pd.read_csv("AgeGroupDetails.csv?dl=0") 
india_covid_19 = pd.read_csv("covid_19_india.csv?dl=0")
hospital_beds = pd.read_csv("HospitalBedsIndia.csv?dl=0")
world_population = pd.read_csv("datasets_507962_1091873_population_by_country_2020.csv?dl=0")
confirmed_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
deaths_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
recovered_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')

# %% [markdown]
# Question-1: Visualize Active, Recovering, and Deaths in Hotspot Countries and write down the inference

# %%
import matplotlib.dates as mdates
hotspots = ['China','Germany','Iran','Italy','Spain','US','Korea, South','France','Turkey','United Kingdom','India']
dates = list(confirmed_df.columns[4:])
dates = list(pd.to_datetime(dates))
dates_india = dates[8:]

#creating a new dataframe and group country by region
df1 = confirmed_df.groupby('Country/Region').sum().reset_index()
df2 = deaths_df.groupby('Country/Region').sum().reset_index()
df3 = recovered_df.groupby('Country/Region').sum().reset_index()

# create a empty dictionaries to store new data
global_confirmed = {}
global_death = {}
global_recovered = {}
global_active = {}

for country in hotspots:
  k =df1[df1['Country/Region'] == country].loc[:,'1/30/20':]
  global_confirmed[country] = k.values.tolist()[0]

  k =df2[df2['Country/Region'] == country].loc[:,'1/30/20':]
  global_death[country] = k.values.tolist()[0]

  k =df3[df3['Country/Region'] == country].loc[:,'1/30/20':]
  global_recovered[country] = k.values.tolist()[0]

for country in hotspots:
  k = list(map(int.__sub__, global_confirmed[country], global_death[country]))
  global_active[country] = list(map(int.__sub__, k, global_recovered[country]))

#visualize the above data
fig = plt.figure(figsize=(15,15))
plt.suptitle('Active, Recovered, Death in Hotspot Countries ',fontsize = 20,y=1.0)
#plt.legend
k = 0
for i in range(1,12):
  ax = fig.add_subplot(6,2,i)
  ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%b'))
  ax.bar(dates_india,global_active[hotspots[k]],color='green',alpha=0.6,label='Active');
  ax.bar(dates_india,global_recovered[hotspots[k]],color='blue',label='Death');
  ax.bar(dates_india,global_death[hotspots[k]],color='red',label='Death');
  plt.title(hotspots[k])
  handles, labels = ax.get_legend_handles_labels()
  fig.legend(handles, labels, loc='upper left')
  k=k+1

plt.tight_layout(pad=3.0)

# %% [markdown]
# Question-2: Visualize COVID-19 trend in India

# %%
dates = list(confirmed_df.columns[4:])
dates = list(pd.to_datetime(dates))
dates_india = dates[8:]
#creating a new dataframe and group country by region
df1 = confirmed_df.groupby('Country/Region').sum().reset_index()
df2 = deaths_df.groupby('Country/Region').sum().reset_index()
df3 = recovered_df.groupby('Country/Region').sum().reset_index()
#add the values to the list
k = df1[df1['Country/Region']=='India'].loc[:,'1/30/20':]
india_confirmed = k.values.tolist()[0]
k = df2[df2['Country/Region']=='India'].loc[:,'1/30/20':]
india_deaths = k.values.tolist()[0]
k = df3[df3['Country/Region']=='India'].loc[:,'1/30/20':]
india_recovered = k.values.tolist()[0]
#plotting
plt.figure(figsize= (15,10))
plt.xticks(rotation = 90 ,fontsize = 11)
plt.yticks(fontsize = 10)
plt.xlabel("Dates",fontsize = 20)
plt.ylabel('Total cases',fontsize = 20)
plt.title("Total Confirmed, Recovered, Death in India" , fontsize = 25)
ax1 = plt.plot_date(y= india_confirmed,x= dates_india,label = 'Confirmed',linestyle ='-',color = 'b')
ax2 = plt.plot_date(y= india_recovered,x= dates_india,label = 'Recovered',linestyle ='-',color = 'g')
ax3 = plt.plot_date(y= india_deaths,x= dates_india,label = 'Death',linestyle ='-',color = 'r')
plt.legend();

# %% [markdown]
# Question-3: Compare the Active, Recovered and Death rates in India with other countries and Write down the
# inference

# %%
countries = ['China','US', 'Italy', 'Spain', 'France','India']
#creating a new list and group country by region
global_confirmed = []
global_recovered = []
global_deaths = []
global_active = []
for country in countries:
  k =df1[df1['Country/Region'] == country].loc[:,'1/30/20':]
  global_confirmed.append(k.values.tolist()[0])
  k =df2[df2['Country/Region'] == country].loc[:,'1/30/20':]
  global_deaths.append(k.values.tolist()[0])
  k =df3[df3['Country/Region'] == country].loc[:,'1/30/20':]
  global_deaths.append(k.values.tolist()[0])

#plotting
plt.figure(figsize= (15,10))
plt.xticks(rotation = 90 ,fontsize = 11)
plt.yticks(fontsize = 10)
plt.xlabel("Dates",fontsize = 20)
plt.ylabel('Total cases',fontsize = 20)
plt.title("Comparison with other Countries" , fontsize = 20)

for i in range(len(countries)):
  plt.plot_date(y= global_confirmed[i],x= dates_india,label = countries[i],linestyle ='-')
plt.legend();

# %% [markdown]
# Question-4: People of which age are affected the most? Visualize the same with different age group and write down
# the inference

# %%
labels = list(age_details['AgeGroup'])
sizes = list(age_details['TotalCases'])
explode = []
for i in labels:
  explode.append(0.05)
# Plotting
plt.figure(figsize= (15,10))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=9, explode =explode)
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title('India - Age Group wise Distribution',fontsize = 20)
plt.axis('equal')
plt.tight_layout()

# %% [markdown]
# Question-5: Create a color map to represent the LIVE status of COVID-19 in all the states of INDIA

# %%
import requests
# for scraping web contents
from bs4 import BeautifulSoup
import json
# get response from the web page
response = requests.get('https://api.covid19india.org/state_test_data.json')
# get contents from the response
content = response.content
# parse the json file
parsed = json.loads(content)
# keys
parsed.keys()
# Out:
# dict_keys(['states_tested_data'])

# %%
# save data in a dataframe
tested = pd.DataFrame(parsed['states_tested_data'])
# first few rows
tested.tail()
# Out:
#       bedsoccupiednormalisolation  ...   updatedon
# 12218                      30.00%  ...  09/04/2021
# 12219                      32.92%  ...  10/04/2021
# 12220                      34.94%  ...  11/04/2021
# 12221                      28.15%  ...  12/04/2021
# 12222                      31.09%  ...  13/04/2021
#
# [5 rows x 55 columns]

# %%
import sys

# %%
# fix datatype
tested['updatedon'] = pd.to_datetime(tested['updatedon'])

# %%
tested.to_csv('updated_tests_latest_state_level.csv', index=False)
state_test_cases = tested.groupby(['updatedon','state'])['totaltested','populationncp2019projection','testpositivityra te',
'testsperpositivecase', 'testsperthousand','totalpeoplecurrentlyinquarantine'].max().reset_index()
state_test_cases.head(36)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-ba05fb57a491> in <module>()
#       1 tested.to_csv('updated_tests_latest_state_level.csv', index=False)
# ----> 2 state_test_cases = tested.groupby(['updatedon','state'])['totaltested','populationncp2019projection','testpositivityra te',
#       3 'testsperpositivecase', 'testsperthousand','totalpeoplecurrentlyinquarantine'].max().reset_index()
#       4 state_test_cases.head(36)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1608                 stacklevel=2,
#    1609             )
# -> 1610         return super().__getitem__(key)
#    1611
# ...

# %%
tested.columns
# Out:
# Index(['bedsoccupiednormalisolation',
#        'casesoutsidehomeisolationi.einstitutionalisolationhospitaletc.',
#        'covidenquirycalls', 'cumulativenumberofasymptomaticcases',
#        'cumulativenumberofsymptomaticcases', 'cumulativepeopleinhomeisolation',
#        'cumulativepeopleinobservation', 'cumulativepeopleinquarantine',
#        'cumulativepeopleinsurveillance', 'femaleconfirmedcases',
#        'femaledeceasedcases', 'maleconfirmedcases', 'maledeceasedcases',
#        'negative', 'numberofcontainmentzones', 'othertests', 'peopleonicubeds',
#        'peopleono2beds', 'peopleonventilator',
#        'peoplereleasedfromhomeisolation', 'peoplereleasedfromobservation',
#        'peoplereleasedfromsurveillance', 'positive', 'ratrapidantigentest',
#        'rt-pcrtestincludestruenatcbnaatcrispr', 'source1', 'source2',
#        'source3', 'source4', 'state', 'tagnatureofcases',
#        'tagpeopleinisolation', 'tagpeopleinquarantine',
# ...
